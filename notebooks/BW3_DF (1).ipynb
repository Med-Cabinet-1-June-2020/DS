# %%
import pandas as pd 
import numpy as np
import urllib.request, json
import requests

# %%
url = ('http://strainapi.evanbusse.com/OEdbKsl/strains/search/all')

# %%
import requests
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'Afpak': {'effects': {'medical': ['Depression',
#     'Insomnia',
#     'Pain',
#     'Stress',
#     'Lack of Appetite'],
#    'negative': ['Dizzy'],
#    'positive': ['Relaxed', 'Hungry', 'Happy', 'Sleepy']},
#   'flavors': ['Earthy', 'Chemical', 'Pine'],
#   'id': 1,
#   'race': 'hybrid'},
#  'African': {'effects': {'medical': ['Depression',
#     'Pain',
#     'Stress',
#     'Lack of Appetite',
#     'Nausea',
#     'Headache'],
#    'negative': ['Dry Mouth'],
#    'positive': ['Euphoric', 'Happy', 'Creative', 'Energetic', 'Talkative']},
#   'flavors': ['Spicy/Herbal', 'Pungent', 'Earthy'],
#   'id': 2,
#   'race': 'sativa'},
#  'Afternoon Delight': {'effects': {'medical': ['Depression',
#     'Insomnia',
#     'Pain',
#     'Stress',
#     'Cramps',
#     'Headache'],
#    'negative': ['Dizzy', 'Dry Mouth', 'Paranoid'],
#    'positive': ['Relaxed', 'Hungry', 'Euphoric', 'Uplifted', 'Tingly']},
#   'flavors': ['Pepper', 'Flowery', 'Pine'],
#   'id': 3,
#   'race': 'hybrid'},
# ...

# %%
df = pd.DataFrame(data)

df.head()
# Out:
#                                                      Afpak  ...                                        ʻAlenuihāhā
# id                                                       1  ...                                               2162
# race                                                hybrid  ...                                             hybrid
# flavors                           [Earthy, Chemical, Pine]  ...                       [Sweet, Tropical, Pineapple]
# effects  {'positive': ['Relaxed', 'Hungry', 'Happy', 'S...  ...  {'positive': ['Euphoric', 'Happy', 'Creative',...
#
# [4 rows x 1970 columns]

# %%
df.columns
# Out:
# Index(['Afpak', 'African', 'Afternoon Delight', 'Afwreck', 'Agent Orange',
#        'Agent Tangie', 'Alaska', 'Alaska Thunder Grape', 'Alaskan Ice',
#        'Alaskan Thunder Fuck',
#        ...
#        'Yogi Diesel', 'Yumboldt', 'Yummy', 'Zen', 'Zeta Sage', 'Zeus OG',
#        'Zkittlez', 'Zombie OG', 'Zoom Pie', 'ʻAlenuihāhā'],
#       dtype='object', length=1970)

# %%
df = df.T

df.head()
# Out:
#                   id  ...                                            effects
# Afpak              1  ...  {'positive': ['Relaxed', 'Hungry', 'Happy', 'S...
# African            2  ...  {'positive': ['Euphoric', 'Happy', 'Creative',...
# Afternoon Delight  3  ...  {'positive': ['Relaxed', 'Hungry', 'Euphoric',...
# Afwreck            4  ...  {'positive': ['Relaxed', 'Happy', 'Creative', ...
# Agent Orange       5  ...  {'positive': ['Relaxed', 'Euphoric', 'Happy', ...
#
# [5 rows x 4 columns]

# %%
df = df.reset_index().set_index('id')

df.head()
# Out:
#                 index  ...                                            effects
# id                     ...
# 1               Afpak  ...  {'positive': ['Relaxed', 'Hungry', 'Happy', 'S...
# 2             African  ...  {'positive': ['Euphoric', 'Happy', 'Creative',...
# 3   Afternoon Delight  ...  {'positive': ['Relaxed', 'Hungry', 'Euphoric',...
# 4             Afwreck  ...  {'positive': ['Relaxed', 'Happy', 'Creative', ...
# 5        Agent Orange  ...  {'positive': ['Relaxed', 'Euphoric', 'Happy', ...
#
# [5 rows x 4 columns]

# %%
df = df.rename(columns={"index": "Strain"})
df = df.reset_index()
df.head()
# Out:
#    id  ...                                            effects
# 0   1  ...  {'positive': ['Relaxed', 'Hungry', 'Happy', 'S...
# 1   2  ...  {'positive': ['Euphoric', 'Happy', 'Creative',...
# 2   3  ...  {'positive': ['Relaxed', 'Hungry', 'Euphoric',...
# 3   4  ...  {'positive': ['Relaxed', 'Happy', 'Creative', ...
# 4   5  ...  {'positive': ['Relaxed', 'Euphoric', 'Happy', ...
#
# [5 rows x 5 columns]

# %%
df.shape
# Out:
# (1970, 5)

# %%
df2 = pd.json_normalize(df['effects'])
df2 = df2.reset_index()
df2.head()
# Out:
#    index  ...                                            medical
# 0      0  ...  [Depression, Insomnia, Pain, Stress, Lack of A...
# 1      1  ...  [Depression, Pain, Stress, Lack of Appetite, N...
# 2      2  ...  [Depression, Insomnia, Pain, Stress, Cramps, H...
# 3      3  ...  [Pain, Stress, Headache, Fatigue, Headaches, M...
# 4      4  ...  [Depression, Pain, Stress, Nausea, Headache, H...
#
# [5 rows x 4 columns]

# %%
df2.shape
# Out:
# (1970, 4)

# %%
df3 = pd.concat([df,df2], axis=1)

df3.head(10)
# Out:
#    id  ...                                            medical
# 0   1  ...  [Depression, Insomnia, Pain, Stress, Lack of A...
# 1   2  ...  [Depression, Pain, Stress, Lack of Appetite, N...
# 2   3  ...  [Depression, Insomnia, Pain, Stress, Cramps, H...
# 3   4  ...  [Pain, Stress, Headache, Fatigue, Headaches, M...
# 4   5  ...  [Depression, Pain, Stress, Nausea, Headache, H...
# 5   6  ...  [Depression, Stress, Cramps, Fatigue, Eye Pres...
# 6   8  ...  [Depression, Pain, Stress, Lack of Appetite, H...
# 7   9  ...                       [Pain, Stress, Eye Pressure]
# 8  10  ...     [Depression, Pain, Stress, Fatigue, Headaches]
# 9  11  ...  [Depression, Pain, Stress, Lack of Appetite, H...
#
# [10 rows x 9 columns]

# %%
df3 = df3.drop(columns=['effects','index']).set_index('id')

df3.shape
df3.head()
# Out:
#                Strain  ...                                            medical
# id                     ...
# 1               Afpak  ...  [Depression, Insomnia, Pain, Stress, Lack of A...
# 2             African  ...  [Depression, Pain, Stress, Lack of Appetite, N...
# 3   Afternoon Delight  ...  [Depression, Insomnia, Pain, Stress, Cramps, H...
# 4             Afwreck  ...  [Pain, Stress, Headache, Fatigue, Headaches, M...
# 5        Agent Orange  ...  [Depression, Pain, Stress, Nausea, Headache, H...
#
# [5 rows x 6 columns]

# %%
df3.shape
# Out:
# (1970, 6)

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/Med-Cabinet-1-June-2020/DS/master/cannabis.csv')

df4.head()
# Out:
#            Strain  ...                                        Description
# 0          100-Og  ...  $100 OG is a 50/50 hybrid strain that packs a ...
# 1  98-White-Widow  ...  The ‘98 Aloha White Widow is an especially pot...
# 2            1024  ...  1024 is a sativa-dominant hybrid bred in Spain...
# 3        13-Dawgs  ...  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 4        24K-Gold  ...  Also known as Kosher Tangie, 24k Gold is a 60%...
#
# [5 rows x 6 columns]

# %%
df4['Strain'] = df4['Strain'].str.replace('-', ' ')

df4.head()
# Out:
#            Strain  ...                                        Description
# 0          100 Og  ...  $100 OG is a 50/50 hybrid strain that packs a ...
# 1  98 White Widow  ...  The ‘98 Aloha White Widow is an especially pot...
# 2            1024  ...  1024 is a sativa-dominant hybrid bred in Spain...
# 3        13 Dawgs  ...  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 4        24K Gold  ...  Also known as Kosher Tangie, 24k Gold is a 60%...
#
# [5 rows x 6 columns]

# %%
df4.shape
# Out:
# (2351, 6)

# %%
df5 = pd.merge(df3, df4, how='inner', on='Strain')

df5.head()
# Out:
#               Strain  ...                                        Description
# 0              Afpak  ...  Afpak, named for its direct Afghani and Pakist...
# 1            African  ...  African refers to the indigenous varieties of ...
# 2  Afternoon Delight  ...  Afternoon Delight, created by Colorado Seed In...
# 3            Afwreck  ...  Afwreck is a hybrid cross of Afghani and Train...
# 4       Agent Orange  ...  Don’t let the name scare you! The only herbici...
#
# [5 rows x 11 columns]

# %%
df6 = df5.drop(columns=['Effects', 'Flavor', 'race'])
df6 = df6.rename(columns={"flavors": "Flavors", "positive": "Positive",
                          "negative": "Negative", "medical": "Medical"})
df6.head()
# Out:
#               Strain  ...                                        Description
# 0              Afpak  ...  Afpak, named for its direct Afghani and Pakist...
# 1            African  ...  African refers to the indigenous varieties of ...
# 2  Afternoon Delight  ...  Afternoon Delight, created by Colorado Seed In...
# 3            Afwreck  ...  Afwreck is a hybrid cross of Afghani and Train...
# 4       Agent Orange  ...  Don’t let the name scare you! The only herbici...
#
# [5 rows x 8 columns]

# %%
df6.shape
# Out:
# (1495, 8)

# %%
df6.to_csv('final_cannabis.csv', index=False)

# %%
from google.colab import files
files.download("final_cannabis.csv")

# %%
df7 = df5.drop(columns=['Effects', 'Flavor'])
df7 = df7.rename(columns={"Strain": "strain"})
df7.head()
# Out:
#               strain  ...                                        Description
# 0              Afpak  ...  Afpak, named for its direct Afghani and Pakist...
# 1            African  ...  African refers to the indigenous varieties of ...
# 2  Afternoon Delight  ...  Afternoon Delight, created by Colorado Seed In...
# 3            Afwreck  ...  Afwreck is a hybrid cross of Afghani and Train...
# 4       Agent Orange  ...  Don’t let the name scare you! The only herbici...
#
# [5 rows x 9 columns]

# %%
df7.to_csv('compatible_cannabis.csv', index=False)

# %%
files.download("compatible_cannabis.csv")

# %%
from sqlalchemy import create_engine
engine = create_engine('postgres://ieguuqxs:3pfznX...@ruby.db.elephantsql.com:5432/ieguuqxs')

# %%
df7.to_sql('medcabinet', engine)
